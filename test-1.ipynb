# %%
# Out:
# Processing city: gent/9000
# Finished processing city: gent/9000
# Processing city: mariakerke/9030
# Finished processing city: mariakerke/9030
# Processing city: drongen/9031
# Finished processing city: drongen/9031
# Processing city: wondelgem/9032
# Finished processing city: wondelgem/9032
# Processing city: aalst/9300
# Finished processing city: aalst/9300
# Processing city: hofstade/9308
# Finished processing city: hofstade/9308
# Processing city: st-niklaas/9100
# Finished processing city: st-niklaas/9100
# Processing city: eine/9700
# Finished processing city: eine/9700
# Processing city: dendermonde/9200
# Finished processing city: dendermonde/9200
# Processing city: lokeren/9160
# Finished processing city: lokeren/9160
# Processing city: geraardsbergen/9500
# Finished processing city: geraardsbergen/9500
# Processing city: eeklo/9900
# Finished processing city: eeklo/9900
# Processing city: deinze/9800
# Finished processing city: deinze/9800
# Processing city: ninove/9400
# ...
